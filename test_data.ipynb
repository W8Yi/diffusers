# %%
import torch
import os
import numpy as np

save_location_prefix = "/data/local/weiyi"
save_location = "test"
save_location = os.path.join(save_location_prefix, save_location)

# %%
h_space_list = np.load(os.path.join(save_location, "test1.npy"))
print(h_space_list.shape)
# Out:
# (30, 4, 1280, 8, 8)

# %%
h_temp = h_space_list[0][0]
print(h_temp.shape)
print(h_temp[0, :, :])
# Out:
# (1280, 8, 8)
# [[-5.564899   -1.9411457  -2.4862287  -1.8251561   0.4553544  -1.038789
#   -1.0963652  -2.1600204 ]
#  [-2.3135078  -1.449271   -1.3084238   1.5003762   1.0579121   1.6738244
#    0.5335039  -4.0814037 ]
#  [-1.5531051   1.8759277  -0.26545393  1.5685877   1.3358773  -1.0947936
#   -1.6176908  -3.5601313 ]
#  [-3.933348   -2.7158384  -1.8035097  -2.3098185   1.1515397  -0.4167416
#   -0.7500458  -2.7310748 ]
#  [-3.719139   -2.9577541  -2.1138544  -3.5200024  -4.273599    0.3978842
#   -1.9885217  -1.8388033 ]
#  [-3.7049184  -3.857583   -2.1662626  -3.214293   -6.2616158  -1.8076967
#   -2.6878543  -4.261061  ]
#  [-2.1514494  -1.5369859  -1.6028321  -2.1934373  -4.205161    0.27688813
#   -1.1330972  -3.8384452 ]
#  [-3.3464162  -5.2230487  -4.081308   -3.4127078  -5.2182493  -4.0170445
#   -2.8608105  -5.178941  ]]

# %%
h_temp = h_space_list[0][1]
print(h_temp.shape)
print(h_temp[0, :, :])
# Out:
# (1280, 8, 8)
# [[-1.6307807   2.1017706   1.049979   -1.0183604   0.7053551  -1.3785305
#   -1.8696445  -0.57243574]
#  [ 3.0594149   4.1122847  -2.3427262  -2.6833875  -2.081348   -3.0918763
#   -3.3304305  -0.7103055 ]
#  [ 1.88475    -0.16358173 -5.3357167   1.5814172  -1.3487966  -2.3921967
#   -5.052182   -3.2511559 ]
#  [-2.94314    -3.6635237  -2.3399239   0.0930109   0.28312755 -1.6491592
#   -4.797112   -0.9024847 ]
#  [-2.062243   -1.7724512  -3.2208729  -0.7720957  -3.532074   -1.3974676
#   -2.2580316  -2.682233  ]
#  [-3.1966376  -1.9052083  -2.162702   -0.42173195 -2.4708712  -5.295743
#   -3.4929748  -2.4632912 ]
#  [-2.7711616  -3.333749   -1.8412131  -5.7937884  -2.0931723  -3.7973425
#   -2.857673   -3.30555   ]
#  [-5.1201434  -3.53176    -3.9611793  -4.7402654  -1.9846232  -5.104315
#   -5.29336    -4.7801437 ]]

# %%
h_temp = h_space_list[0][2]
print(h_temp.shape)
print(h_temp[0, :, :])
# Out:
# (1280, 8, 8)
# [[-1.4639049  -0.03334346  0.8578816   1.4590364   1.1358829   0.58193254
#   -0.42325205  0.18829077]
#  [ 0.8483084   0.8054226   3.530404    3.237131    1.8055444   2.8646646
#    0.8533168  -1.7099483 ]
#  [ 3.8887098   7.6445875   1.1091696   0.2099216  -0.74858034  3.2523363
#    1.6897627   0.8387269 ]
#  [ 2.8802304   3.2377293  -2.9290333  -6.2633734  -3.5520089   0.8805449
#    2.0828872   2.997376  ]
#  [ 2.9632823   0.1780733  -3.8832557  -5.8919516  -4.828931   -1.2072471
#   -4.05369     2.1631358 ]
#  [ 0.9815155   1.1022121   1.6653678  -0.9194137  -2.1903055   1.9200963
#    1.2815142   1.7059517 ]
#  [ 4.0143356   3.790268    4.163807    2.728638    0.91842175  6.2013793
#    5.9588532   3.3453932 ]
#  [ 0.6190246  -0.39120013  0.9986292   2.0679688  -0.13447654  2.6985507
#    1.1357384  -1.8041453 ]]

# %%
h_temp = h_space_list[0][3]
print(h_temp.shape)
print(h_temp[0, :, :])
# Out:
# (1280, 8, 8)
# [[-0.32370734  1.6106915   2.503367    3.3615031   3.2902765   3.0511985
#    1.081586    1.6159661 ]
#  [ 4.1429834   2.1107807   1.9746777   2.9662962   2.5125566   3.0256755
#   -0.44060826  0.4397533 ]
#  [ 3.7103913   0.7769283   0.24787521  0.7586147   0.09381832  1.7435809
#    2.1864612   1.7462816 ]
#  [ 0.16111243  0.41292942 -1.2884924  -3.4716952  -2.0679696   0.00981748
#    1.3529943   3.365864  ]
#  [ 0.4753703  -0.13055648 -4.0575666  -3.8237894  -3.5007186  -0.60948753
#   -1.0489324   1.0374836 ]
#  [ 0.5488963  -1.7355193  -1.7193516  -0.7003465  -0.26052594  1.2445136
#    3.220427    1.2892096 ]
#  [ 2.133906    0.34230185  1.7557122   2.6984947   4.4184256   2.7124984
#    2.6142712  -1.2077222 ]
#  [ 3.6793132   1.8444409   2.638991    2.0057435   2.2496567   2.5749106
#    1.8747498   0.6200316 ]]
