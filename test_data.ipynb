# %%
import torch
import os
import numpy as np

save_location_prefix = "/data/local/weiyi"
save_location = "test"
save_location = os.path.join(save_location_prefix, save_location)

# %%
# we observe the first latent vector is for random noise, 
# and second latent vector is for the class label

# %%
h_space_list = np.load(os.path.join(save_location, "test1.npy"))
print(h_space_list.shape)

h_space_list2 = np.load(os.path.join(save_location, "test2.npy"))
print(h_space_list2.shape)
# Out:
# (30, 2, 1280, 8, 8)
# (30, 2, 1280, 8, 8)

# %%
h_temp = h_space_list[0][0]
print(h_temp.shape)
print(h_temp[0, :, :])
# Out:
# (1280, 8, 8)
# [[-5.5662146  -1.9413099  -2.486113   -1.8251898   0.45484647 -1.0384175
#   -1.0974463  -2.1616132 ]
#  [-2.314028   -1.4478312  -1.3091018   1.5009519   1.0585895   1.6754096
#    0.5334356  -4.082477  ]
#  [-1.5546644   1.8755649  -0.2659757   1.5688866   1.3361956  -1.0958643
#   -1.6173966  -3.5589235 ]
#  [-3.934007   -2.71797    -1.8052179  -2.3099966   1.1540377  -0.41653347
#   -0.7541499  -2.7324474 ]
#  [-3.7198396  -2.9571152  -2.1149936  -3.5210013  -4.2720037   0.39785606
#   -1.9893854  -1.8399224 ]
#  [-3.7033558  -3.8563905  -2.1676598  -3.2143955  -6.2593584  -1.8091899
#   -2.688622   -4.25982   ]
#  [-2.1514452  -1.5373882  -1.6035515  -2.1952338  -4.205509    0.27683157
#   -1.132406   -3.8377528 ]
#  [-3.3457367  -5.2241354  -4.079088   -3.4146361  -5.218239   -4.014842
#   -2.8586755  -5.1773696 ]]

# %%
h_temp2 = h_space_list2[0][0]
print(h_temp2.shape)
print(h_temp2[0, :, :])
# Out:
# (1280, 8, 8)
# [[-5.5662146  -1.9413099  -2.486113   -1.8251898   0.45484647 -1.0384175
#   -1.0974463  -2.1616132 ]
#  [-2.314028   -1.4478312  -1.3091018   1.5009519   1.0585895   1.6754096
#    0.5334356  -4.082477  ]
#  [-1.5546644   1.8755649  -0.2659757   1.5688866   1.3361956  -1.0958643
#   -1.6173966  -3.5589235 ]
#  [-3.934007   -2.71797    -1.8052179  -2.3099966   1.1540377  -0.41653347
#   -0.7541499  -2.7324474 ]
#  [-3.7198396  -2.9571152  -2.1149936  -3.5210013  -4.2720037   0.39785606
#   -1.9893854  -1.8399224 ]
#  [-3.7033558  -3.8563905  -2.1676598  -3.2143955  -6.2593584  -1.8091899
#   -2.688622   -4.25982   ]
#  [-2.1514452  -1.5373882  -1.6035515  -2.1952338  -4.205509    0.27683157
#   -1.132406   -3.8377528 ]
#  [-3.3457367  -5.2241354  -4.079088   -3.4146361  -5.218239   -4.014842
#   -2.8586755  -5.1773696 ]]

# %%
h_temp = h_space_list[0][1]
print(h_temp.shape)
print(h_temp[0, :, :])
# Out:
# (1280, 8, 8)
# [[-4.0042396  -1.122652   -0.82736737  0.36970508  1.3111855   1.32967
#    0.38961923 -1.1836308 ]
#  [-1.9769652  -0.19191885 -0.685796    2.1626816   0.3020332   2.5223408
#    0.6234002  -1.1980667 ]
#  [-1.0377381   1.3022637  -3.2275574  -1.0500383  -0.75408953 -1.438808
#   -3.7489433  -0.8928075 ]
#  [-3.4776218  -4.9701195  -4.055973   -2.3443172  -3.943293   -0.01728129
#   -1.6625946  -3.0580678 ]
#  [-2.8559058  -3.5392134  -2.451899   -4.815891   -4.6699476   3.343764
#   -2.687462   -2.5159583 ]
#  [-2.9828815  -5.5712914  -4.4329715  -3.7877762  -7.898135   -7.3165317
#   -6.3577623  -3.5045056 ]
#  [ 0.3316102  -1.2227274   0.29952264  2.560991   -2.2182567   1.1225902
#    0.9990611  -0.594999  ]
#  [-2.7947009  -2.2962704  -2.2722454  -1.6065018  -2.544449   -3.2441576
#   -2.3132453  -2.9614818 ]]

# %%
h_temp2 = h_space_list2[0][1]
print(h_temp2.shape)
print(h_temp2[0, :, :])
# Out:
# (1280, 8, 8)
# [[-4.689534   -0.8804692  -0.71381944  0.930719    2.521477    1.3994725
#    0.20389658 -2.634954  ]
#  [-1.8810241   0.96759653  2.1326828   4.9285126   3.3424027   2.6574016
#    0.06733036 -2.8851013 ]
#  [-0.03217423  3.2856212   3.1585166   3.964658    2.6077893   2.5390317
#    0.4656129  -1.9206803 ]
#  [-0.03022826  2.4961956   1.2202963  -1.6232913  -0.21354699  4.226622
#    4.338921    0.44667435]
#  [-0.45314515  0.23321939  0.73851216 -0.29780024 -2.7224228   3.2253551
#   -0.9729533   0.22297728]
#  [-0.8826832  -1.1062009  -1.9499335  -0.635272   -2.5674849  -0.90163445
#   -4.0997124  -2.7804096 ]
#  [-1.7585056  -0.6804106  -0.39210546 -0.34378862 -3.6310682  -0.7289505
#   -2.9921696  -2.5249002 ]
#  [-2.7341516  -0.9577389  -1.8060722  -3.0108361  -6.0527706  -3.3308647
#   -2.0655928  -4.5060797 ]]

# %%
h_space_list = np.load(os.path.join(save_location, "test3.npy"))
print(h_space_list.shape)

h_space_list2 = np.load(os.path.join(save_location, "test4.npy"))
print(h_space_list2.shape)

h_space_list3 = np.load(os.path.join(save_location, "test5.npy"))
print(h_space_list2.shape)
# Out:
# (30, 2, 1280, 8, 8)
# (30, 2, 1280, 8, 8)
# (30, 2, 1280, 8, 8)

# %%
h_temp = h_space_list[0][1]
print(h_temp.shape)
print(h_temp[0, :, :])
# Out:
# (1280, 8, 8)
# [[-4.689534   -0.8804692  -0.71381944  0.930719    2.521477    1.3994725
#    0.20389658 -2.634954  ]
#  [-1.8810241   0.96759653  2.1326828   4.9285126   3.3424027   2.6574016
#    0.06733036 -2.8851013 ]
#  [-0.03217423  3.2856212   3.1585166   3.964658    2.6077893   2.5390317
#  [-3.3457367  -5.2241354  -4.079088   -3.4146361  -5.218239   -4.014842
#   -2.8586755  -5.1773696 ]]

# %%
np.sum((h_temp - h_temp2))
# Out:
# 0.0

# %%
np.sum((h_temp2 - h_temp3))
# Out:
# 0.0

# %%
np.sum((h_temp - h_temp3))
# Out:
# 0.0

# %%
np.sum((h_space_list6[0][0] - h_temp3))
# Out:
# -0.21583211

# %%
h_space_list6 = np.load(os.path.join(save_location, "test6.npy"))
print(h_space_list6.shape)
# Out:
# (30, 5, 1280, 8, 8)

# %%
h_space_list6[0][0][0, :, :]
# Out:
# array([[-5.564438  , -1.941122  , -2.484831  , -1.825352  ,  0.45332977,
#         -1.0398036 , -1.0978115 , -2.1606388 ],
#        [-2.3110874 , -1.4486272 , -1.3087294 ,  1.4996308 ,  1.0580821 ,
#          1.6735935 ,  0.5311067 , -4.0819635 ],
#        [-1.5547662 ,  1.875459  , -0.26618886,  1.5706722 ,  1.3364089 ,
#         -1.0963097 , -1.6194367 , -3.5607986 ],
#        [-3.9343214 , -2.7165105 , -1.8025783 , -2.3117516 ,  1.1538979 ,
#         -0.41768765, -0.75175667, -2.730575  ],
#        [-3.7207701 , -2.9581459 , -2.1126542 , -3.5203824 , -4.2710953 ,
#          0.39561063, -1.9908423 , -1.8394153 ],
#        [-3.70554   , -3.8569987 , -2.1678576 , -3.213877  , -6.259633  ,
#         -1.8096099 , -2.6881917 , -4.2597046 ],
#        [-2.15205   , -1.5368072 , -1.6032361 , -2.1940327 , -4.2070546 ,
#          0.27592278, -1.132817  , -3.8379812 ],
#        [-3.345397  , -5.2241044 , -4.0798497 , -3.4125514 , -5.2164063 ,
# ...

# %%
h_space_list6[0][1][0, :, :]
# Out:
# array([[-0.310269  ,  0.9974929 ,  2.531625  ,  2.27054   ,  3.84824   ,
#          2.0121832 ,  1.3298969 ,  1.0221694 ],
#        [ 1.0224115 ,  0.3300593 ,  2.8419483 ,  3.5406098 ,  3.539578  ,
#          1.3135629 ,  0.6371391 , -0.28816342],
#        [ 1.7980273 , -2.5419343 , -0.7346649 , -0.9986588 , -0.3709128 ,
#         -4.4747877 , -1.5929381 , -0.49647862],
#        [ 0.2447046 , -3.7232609 , -3.5184877 , -2.3962052 , -1.1051631 ,
#         -1.9222264 , -3.8947139 , -1.5385566 ],
#        [-0.2229684 , -3.966047  , -3.4138343 , -2.912889  , -1.9137737 ,
#         -3.2334027 , -6.208232  , -2.5415177 ],
#        [ 0.06875025, -3.7040877 , -0.9099635 , -2.1890337 ,  1.1051824 ,
#         -1.1500924 , -4.8295546 , -0.4760311 ],
#        [ 1.344989  , -0.62055814, -1.9695718 , -2.0442615 ,  1.0334628 ,
#         -2.2944252 , -2.2639725 , -1.5827304 ],
#        [-3.9071991 , -3.0919433 , -1.0611856 , -1.7159803 , -2.517522  ,
# ...
